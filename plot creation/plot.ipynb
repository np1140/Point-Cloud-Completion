# %%
import matplotlib.pyplot as plt
import numpy as np

# Data extracted from the table
models_filtered = ['TopNet', 'GRNet', 'PCN', 'PoinTr', 'AdaPoinTr']
noise_levels = np.array([0.01, 0.05, 0.1, 0.2])

# CD-l2 values for each model (excluding FoldingNet) under different noise conditions
cd_l2_values_filtered = [
    [1.33, 1.60, 2.34, 3.52],  # TopNet
    [1.34, 1.47, 1.72, 2.42],  # GRNet
    [1.33, 1.73, 2.72, 5.22],  # PCN
    [1.25, 1.74, 2.42, 3.74],  # PoinTr
    [0.69, 2.29, 4.54, 8.08]   # AdaPoinTr
]

# Standard deviations for CD-l2 values
cd_l2_std = [
    [0.25, 0.30, 0.64, 1.16],  # TopNet
    [0.27, 0.31, 0.41, 0.82],  # GRNet
    [0.34, 0.45, 0.94, 2.39],  # PCN
    [0.19, 0.22, 0.41, 0.87],  # PoinTr
    [0.13, 0.41, 1.14, 2.36]   # AdaPoinTr
]

plt.figure(figsize=(4, 3))

# Define color palette
colors = plt.cm.tab10(range(len(models_filtered)))

for i, model in enumerate(models_filtered):
    mean = np.array(cd_l2_values_filtered[i])
    std = np.array(cd_l2_std[i])
    
    # Plot the line for mean values
    plt.plot(noise_levels, mean, marker='o', label=model, color=colors[i])
    
    # Add shaded regions for standard deviation with lighter transparency
    # plt.fill_between(noise_levels, mean - std, mean + std, color=colors[i], alpha=0.2)

# Plot customization
# plt.title('Performance of Models (CD-l2) under Various Noise Conditions')
plt.xlabel('Noise Level',fontsize=10)
plt.ylabel('CD-l2',fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xticks(noise_levels)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data extracted from Table 3
models_filtered = ['TopNet', 'GRNet','PCN', 'PoinTr', 'AdaPoinTr']
rotation_conditions = ['Z/Z', 'SO(3)/SO(3)', 'Z/SO(3)']  # Reordering to Z/Z, SO3/SO3, Z/SO3

# CD-l2 values for each model under different rotation conditions (reordered to match x-axis)
cd_l2_values_filtered = [
    [1.73, 3.06, 10.69],  # TopNet
    [1.68, 2.13, 5.78],   # GRNet
    [1.59, 2.45, 20.53],  # PCN
    [1.28, 1.74, 5.54],   # PoinTr
    [1.18, 1.18, 3.78]    # AdaPoinTr
]

# Standard deviations for CD-l2 values (reordered to match x-axis)
cd_l2_std = [
 
    [0.29, 0.61, 0.57],  # TopNet
    [0.22, 0.46, 2.38],  # GRNet
    [0.38, 0.59, 1.15],  # PCN
    [0.26, 0.47, 2.80],  # PoinTr
    [0.19, 0.19, 2.24]   # AdaPoinTr
]

# Create the plot
plt.figure(figsize=(4, 3))

# Define color palette
colors = plt.cm.tab10(range(len(models_filtered)))

# Plotting CD-l2 performance under various rotation conditions
for i, model in enumerate(models_filtered):
    mean = np.array(cd_l2_values_filtered[i])
    std = np.array(cd_l2_std[i])
    
    # Plot the line for mean values
    plt.plot(rotation_conditions, mean, marker='o', label=model, color=colors[i])
    
    # Add shaded regions for standard deviation with lighter transparency
    # plt.fill_between(rotation_conditions, mean - std, mean + std, color=colors[i], alpha=0.2)

# Plot customization
# plt.title('Performance of Models (CD-l2) under Various Rotation Conditions')
plt.xlabel('Rotation', fontsize=10)
plt.ylabel('CD-l2', fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data extracted from the table for CD-S, CD-M, CD-H (excluding FoldingNet)
models = ['TopNet', 'GRNet', 'PCN', 'PoinTr', 'AdaPoinTr']
cd_s = [1.33, 1.33, 1.31, 1.13, 0.44]
cd_m = [1.40, 1.38, 1.35, 1.18, 0.49]
cd_h = [1.51, 1.57, 1.58, 1.44, 0.62]

# Standard deviations for CD values (excluding FoldingNet)
cd_s_std = [0.26, 0.27, 0.38, 0.25, 0.13]
cd_m_std = [0.28, 0.28, 0.35, 0.25, 0.19]
cd_h_std = [0.33, 0.35, 0.43, 0.36, 0.28]

# Combine CD values into one matrix
cd_values = np.array([cd_s, cd_m, cd_h]).T  # Transpose so each row is a model
cd_std = np.array([cd_s_std, cd_m_std, cd_h_std]).T  # Standard deviations
plt.grid(True, linestyle='--', alpha=0.7)

# Create the plot
plt.figure(figsize=(10, 6))

# Define the color palette
colors = plt.cm.tab10(range(3))  # Three colors for CD-S, CD-M, and CD-H

# Plot CD values for all models
for i, metric in enumerate(['CD-S', 'CD-M', 'CD-H']):
    # Plot mean values for each metric
    plt.plot(models, cd_values[:, i], marker='o', label=metric, color=colors[i])
    
    # Add shaded regions for standard deviation
    # plt.fill_between(models, cd_values[:, i] - cd_std[:, i], cd_values[:, i] + cd_std[:, i],
    #                  color=colors[i], alpha=0.2)

# Customizing the plot
# plt.title('Performance of Models under CD Metrics', fontsize=16)
plt.xlabel('Model', fontsize=14)
plt.ylabel('CD Value', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='Metrics', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data extracted from the table for CD-S, CD-M, CD-H (excluding FoldingNet)
models = ['TopNet', 'GRNet', 'PCN', 'PoinTr', 'AdaPoinTr']
cd_s = [1.33, 1.33, 1.31, 1.13, 0.44]
cd_m = [1.40, 1.38, 1.35, 1.18, 0.49]
cd_h = [1.51, 1.57, 1.58, 1.44, 0.62]

# Standard deviations for CD values (excluding FoldingNet)
cd_s_std = [0.26, 0.27, 0.38, 0.25, 0.13]
cd_m_std = [0.28, 0.28, 0.35, 0.25, 0.19]
cd_h_std = [0.33, 0.35, 0.43, 0.36, 0.28]

# Combine CD values into one matrix
cd_values = np.array([cd_s, cd_m, cd_h]).T  # Transpose so each row is a model
cd_std = np.array([cd_s_std, cd_m_std, cd_h_std]).T  # Standard deviations

# Create the plot
plt.figure(figsize=(4, 3))  # Adjust figure size for IEEE double-column format

# Define the color palette
colors = plt.cm.tab10(range(3))  # Three colors for CD-S, CD-M, and CD-H

# Plot CD values for all models
for i, metric in enumerate(['CD-S', 'CD-M', 'CD-H']):
    # Plot mean values for each metric
    plt.plot(models, cd_values[:, i], marker='o', label=metric, color=colors[i], markersize=5, linewidth=1)
    
    # Add shaded regions for standard deviation
    # plt.fill_between(models, cd_values[:, i] - cd_std[:, i], cd_values[:, i] + cd_std[:, i],
    #                  color=colors[i], alpha=0.2)

# Customizing the plot
plt.xlabel('Model', fontsize=10)
plt.ylabel('CD Value', fontsize=10)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)
plt.legend(title='Metrics', fontsize=10, title_fontsize=8, loc='lower left')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()

# Save the plot
plt.savefig('CD_metrics_plot_IEEE.png', dpi=300, bbox_inches='tight')
plt.show()
